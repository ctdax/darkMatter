# %%
import numpy as np
from matplotlib import pyplot as plt
from quickRecoClass import quickReco

# %%
DM = quickReco ('DM','\\Users\\student\\Desktop\\College\\Summer_2020\\Research\\DM_first_model_first_run\\ppTOllxdxd_signal')
P3J = quickReco('PJ','\\Users\\student\\Desktop\\College\\Summer_2020\\Research\\DM_first_model_first_run\\ppTO3j background')
P = quickReco('P','\\Users\\student\\Desktop\\College\\Summer_2020\\Research\\DM_first_model_first_run\\ppTOll background')
P2J = quickReco('P2J', '\\Users\\student\\Desktop\\College\\Summer_2020\\Research\\DM_first_model_first_run\\ppTOljj background')

# %%
#The calculated lumosities for the data sets were:
#Lumosity of P = 55.675 +/- 0.043 pb^-1
#Lumosity of P2J = 434.01 +/- 0.39 pb^-1
#Lumosity of P3J = 1070.78 +/- 0.83 pb^-1
#Lumosity of DM = 216600 +/- 210 pb^-1

#The following are the number each data point needs divided by to rescale all data sets down to 50 pb^-1

PWeight = 1.1135
P2JWeight = 8.680
P3JWeight = 21.42
DMWeight = 4332

# %%
DM.process()
# Out:
# ...Loading file(s)
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_10_xdxd_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_11_xdxd_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_12_xdxd_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_13_xdxd_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_14_xdxd_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_15_xdxd_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_16_xdxd_delphes_events.root
# ...

# %%
P.process()
# Out:
# ...Loading file(s)
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_10_ll_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_11_ll_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_12_ll_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_13_ll_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_14_ll_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_15_ll_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOll background\seed_16_ll_delphes_events.root
# ...

# %%
P2J.process()
# Out:
# ...Loading file(s)
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_10_lljj_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_11_lljj_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_12_lljj_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_13_lljj_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_14_lljj_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_15_lljj_delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOljj background\seed_16_lljj_delphes_events.root
# ...

# %%
P3J.process()
# Out:
# ...Loading file(s)
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_10_lljjj__delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_11_lljjj__delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_12_lljjj__delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_13_lljjj__delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_14_lljjj__delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_15_lljjj__delphes_events.root
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTO3j background\seed_16_lljjj__delphes_events.root
# ...

# %%
PnJetsW = np.empty_like(P.nJets, dtype=float)
for i in range(len(PnJetsW)):
    PnJetsW[i]=1/PWeight
    
P2JnJetsW = np.empty_like(P2J.nJets, dtype=float)
for i in range(len(P2JnJetsW)):
    P2JnJetsW[i]=1/P2JWeight
    
P3JnJetsW = np.empty_like(P3J.nJets, dtype=float)
for i in range(len(P3JnJetsW)):
    P3JnJetsW[i]=1/P3JWeight
    
DMnJetsW = np.empty_like(DM.nJets, dtype=float)
for i in range(len(DMnJetsW)):
    DMnJetsW[i]=1/DMWeight


plt.hist(P.nJets, bins=np.arange(0,10,1), alpha=0.4, label = 'SM ll', weights=PnJetsW)
plt.hist(P2J.nJets, bins=np.arange(0,10,1), alpha=0.4, label='SM ll+jj',weights=P2JnJetsW)
plt.hist(P3J.nJets, bins=np.arange(0,10,1), alpha=0.4, label='SM ll+jjj', weights=P3JnJetsW)
plt.hist(DM.nJets, bins=np.arange(0,10,1), alpha=0.3, label='2HDMa ll+xdxd', weights=DMnJetsW)
plt.title('Number of Jets')
plt.xlabel('Number of Jets')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
PdileptonPTW = np.empty_like(P.dileptonPT, dtype=float)
for i in range(len(PdileptonPTW)):
    PdileptonPTW[i]=1/PWeight
    
P2JdileptonPTW = np.empty_like(P2J.dileptonPT, dtype=float)
for i in range(len(P2JdileptonPTW)):
    P2JdileptonPTW[i]=1/P2JWeight
    
P3JdileptonPTW = np.empty_like(P3J.dileptonPT, dtype=float)
for i in range(len(P3JdileptonPTW)):
    P3JdileptonPTW[i]=1/P3JWeight
    
DMdileptonPTW = np.empty_like(DM.dileptonPT, dtype=float)
for i in range(len(DMdileptonPTW)):
    DMdileptonPTW[i]=1/DMWeight

plt.hist(P.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label = 'SM ll', weights=PdileptonPTW)
plt.hist(P2J.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='SM ll+jj', weights = P2JdileptonPTW)
plt.hist(P3J.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='SM ll+jjj', weights = P3JdileptonPTW)
plt.hist(DM.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='2HDMa ll+xdxd', weights = DMdileptonPTW)
plt.title('Dilepton PT, Lumonized, all 4')
plt.xlabel('Dilepton PT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P2J.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='SM ll+jj', weights = P2JdileptonPTW, color = 'C1')
plt.hist(P3J.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='SM ll+jjj', weights = P3JdileptonPTW, color = 'C2')
plt.hist(DM.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='2HDMa ll+xdxd', weights = DMdileptonPTW, color = 'C3')
plt.title('Dilepton PT, Lumonized, Dropped Largest')
plt.xlabel('Dilepton PT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P3J.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='SM ll+jjj', weights = P3JdileptonPTW, color = 'C2')
plt.hist(DM.dileptonPT, bins=np.arange(0,300,5), alpha=0.4, label='2HDMa ll+xdxd', weights = DMdileptonPTW, color = 'C3')
plt.title('Dilepton PT, Lumonized, Dropped Largest Two')
plt.xlabel('Dilepton PT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
PdileptonMassW = np.empty_like(P.dileptonMass, dtype=float)
for i in range(len(PdileptonMassW)):
    PdileptonMassW[i]=1/PWeight
    
P2JdileptonMassW = np.empty_like(P2J.dileptonMass, dtype=float)
for i in range(len(P2JdileptonMassW)):
    P2JdileptonMassW[i]=1/P2JWeight
    
P3JdileptonMassW = np.empty_like(P3J.dileptonMass, dtype=float)
for i in range(len(P3JdileptonMassW)):
    P3JdileptonMassW[i]=1/P3JWeight
    
DMdileptonMassW = np.empty_like(DM.dileptonMass, dtype=float)
for i in range(len(DMdileptonMassW)):
    DMdileptonMassW[i]=1/DMWeight

plt.hist(P.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='SM ll', weights = PdileptonMassW)
plt.hist(P2J.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='SM ll+jj', weights = P2JdileptonMassW)
plt.hist(P3J.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='SM ll+jjj', weights = P3JdileptonMassW)
plt.hist(DM.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='2HDMa ll+xdxd', weights = DMdileptonMassW)
plt.title('Dilepton Mass, Lumonized, all 4')
plt.xlabel('Dilepton Mass [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P2J.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='SM ll+jj', weights = P2JdileptonMassW, color = 'C1')
plt.hist(P3J.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='SM ll+jjj', weights = P3JdileptonMassW, color = 'C2')
plt.hist(DM.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='2HDMa ll+xdxd', weights = DMdileptonMassW, color = 'C3')
plt.title('Dilepton Mass, Lumonized, Dropped Largest')
plt.xlabel('Dilepton Mass [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P3J.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='SM ll+jjj', weights = P3JdileptonMassW, color = 'C2')
plt.hist(DM.dileptonMass, bins=np.arange(20,160,5), alpha=0.4, label='2HDMa ll+xdxd', weights = DMdileptonMassW, color = 'C3')
plt.title('Dilepton Mass, Lumonized, Dropped Largest 2')
plt.xlabel('Dilepton Mass [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
P_sht_array=[]

for i,arr in enumerate (P.l_scalarHT):
    for j,value in enumerate(arr):
        P_sht_array.append(value)
             
PshtW = np.empty_like(P_sht_array, dtype=float)
for i in range(len(PshtW)):
    PshtW[i]=1/PWeight

P2J_sht_array=[]

for i,arr in enumerate (P2J.l_scalarHT):
    for j,value in enumerate(arr):
        P2J_sht_array.append(value)
        
P2JshtW = np.empty_like(P2J_sht_array, dtype=float)
for i in range(len(P2JshtW)):
    P2JshtW[i]=1/P2JWeight        

        
P3J_sht_array=[]

for i,arr in enumerate (P3J.l_scalarHT):
    for j,value in enumerate(arr):
        P3J_sht_array.append(value)
        
P3JshtW = np.empty_like(P3J_sht_array, dtype=float)
for i in range(len(P3JshtW)):
    P3JshtW[i]=1/P3JWeight 
        
DM_sht_array=[]

for i,arr in enumerate (DM.l_scalarHT):
    for j,value in enumerate(arr):
        DM_sht_array.append(value)
        
        
DMshtW = np.empty_like(DM_sht_array, dtype=float)
for i in range(len(DMshtW)):
    DMshtW[i]=1/DMWeight

# %%
plt.hist(P_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='SM ll', weights = PshtW)
plt.hist(P2J_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='SM ll+jj', weights = P2JshtW)
plt.hist(P3J_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='SM ll+jjj', weights = P3JshtW)
plt.hist(DM_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='2HDMa ll+xdxd', weights = DMshtW)
plt.title('Scalar HT')
plt.xlabel('Scalar HT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P2J_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='SM ll+jj', weights = P2JshtW, color = 'C1')
plt.hist(P3J_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='SM ll+jjj', weights = P3JshtW, color = 'C2')
plt.hist(DM_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='2HDMa ll+xdxd', weights = DMshtW, color = 'C3')
plt.title('Scalar HT')
plt.xlabel('Scalar HT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P3J_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='SM ll+jjj', weights = P3JshtW, color = 'C2')
plt.hist(DM_sht_array, bins=np.arange(0,1000,10), alpha=0.4, label='2HDMa ll+xdxd', weights = DMshtW, color = 'C3')
plt.title('Scalar HT')
plt.xlabel('Scalar HT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
P_met_array=[]

for i,arr in enumerate (P.l_missingET_met):
    for j,value in enumerate(arr):
        P_met_array.append(value)
        
PmetW = np.empty_like(P_met_array, dtype=float)
for i in range(len(PmetW)):
    PmetW[i]=1/PWeight
        
P2J_met_array=[]

for i,arr in enumerate (P2J.l_missingET_met):
    for j,value in enumerate(arr):
        P2J_met_array.append(value)
        
P2JmetW = np.empty_like(P2J_met_array, dtype=float)
for i in range(len(P2JmetW)):
    P2JmetW[i]=1/P2JWeight
        
P3J_met_array=[]

for i,arr in enumerate (P3J.l_missingET_met):
    for j,value in enumerate(arr):
        P3J_met_array.append(value)
        
P3JmetW = np.empty_like(P3J_met_array, dtype=float)
for i in range(len(P3JmetW)):
    P3JmetW[i]=1/P3JWeight
        
DM_met_array=[]

for i,arr in enumerate (DM.l_missingET_met):
    for j,value in enumerate(arr):
        DM_met_array.append(value)
        
DMmetW = np.empty_like(DM_met_array, dtype=float)
for i in range(len(DMmetW)):
    DMmetW[i]=1/DMWeight

# %%
plt.hist(P_met_array, bins=np.arange(0,100,2), alpha=0.4, label = 'SM ll', weights = PmetW, color = 'C0')
plt.hist(P2J_met_array, bins=np.arange(0,100,2), alpha=0.4, label = 'SM ll+jj', weights = P2JmetW, color = 'C1')
plt.hist(P3J_met_array, bins=np.arange(0,100,2), alpha=0.4, label='SM ll+jjj', weights = P3JmetW, color = 'C2')
plt.hist(DM_met_array, bins=np.arange(0,100,2), alpha=0.4, label='2HDMa ll+xdxd', weights = DMmetW, color = 'C3')
plt.title('Missing ET, Lumonized, All 4')
plt.xlabel('Missing ET [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P2J_met_array, bins=np.arange(0,100,2), alpha=0.4, label = 'SM ll+jj', weights = P2JmetW, color = 'C1')
plt.hist(P3J_met_array, bins=np.arange(0,100,2), alpha=0.4, label='SM ll+jjj', weights = P3JmetW, color = 'C2')
plt.hist(DM_met_array, bins=np.arange(0,100,2), alpha=0.4, label='2HDMa ll+xdxd', weights = DMmetW, color = 'C3')
plt.title('Missing ET, Lumonized, Dropped Largest')
plt.xlabel('Missing ET [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(P3J_met_array, bins=np.arange(0,100,2), alpha=0.4, label='SM ll+jjj', weights = P3JmetW, color = 'C2')
plt.hist(DM_met_array, bins=np.arange(0,100,2), alpha=0.4, label='2HDMa ll+xdxd', weights = DMmetW, color = 'C3')
plt.title('Missing ET, Lumonized, Dropped Largest Two')
plt.xlabel('Missing ET [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()
