# %%
import numpy as np
from matplotlib import pyplot as plt
from quickRecoClass import quickReco

# %%
DM = quickReco ('DM','\\Users\\student\\Desktop\\College\\Summer_2020\\Research\\DM_first_model_first_run\\ppTOllxdxd_signal\\seed_1_xdxd_delphes_events.root')

# %%
Cuts = quickReco ('Cuts','\\Users\\student\\Desktop\\College\\Summer_2020\\Research\\DM_first_model_first_run\\5k_ppTO3j_shtcuts_delphes_events.root')

# %%
Cuts.process()
# Out:
# ...Loading file
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\5k_ppTO3j_shtcuts_delphes_events.root
# ...Finished loading branches
# Processed 0 events...
# Event 208 has >2 electron. print (pT, charge)...
# pt: 145.34486389160156, charge: 1
# pt: 97.99871063232422, charge: -1
# pt: 17.506792068481445, charge: 1
# Processed 500 events...
# Processed 1000 events...
# Processed 1500 events...
# Processed 2000 events...
# Processed 2500 events...
# Processed 3000 events...
# Processed 3500 events...
# Processed 4000 events...
# Processed 4500 events...

# %%
DM.process()
# Out:
# ...Loading file
# \Users\student\Desktop\College\Summer_2020\Research\DM_first_model_first_run\ppTOllxdxd_signal\seed_1_xdxd_delphes_events.root
# ...Finished loading branches
# Processed 0 events...
# Event 435 has >2 electron. print (pT, charge)...
# pt: 110.30042266845703, charge: 1
# pt: 40.64705276489258, charge: -1
# pt: 23.151653289794922, charge: 1
# Processed 500 events...
# Processed 1000 events...
# Processed 1500 events...
# Processed 2000 events...
# Processed 2500 events...
# Processed 3000 events...
# Processed 3500 events...
# Processed 4000 events...
# Processed 4500 events...

# %%
DM_sht_array=[]

for i,arr in enumerate (DM.l_scalarHT):
    for j,value in enumerate(arr):
        DM_sht_array.append(value)

# %%
Cuts_sht_array=[]

for i,arr in enumerate (Cuts.l_scalarHT):
    for j,value in enumerate(arr):
        Cuts_sht_array.append(value)

# %%
plt.hist(DM_sht_array, bins=np.arange(0,1500,10), alpha=0.4, label='2HDMa ll+xdxd', color = 'C3')
plt.title('Scalar HT')
plt.xlabel('Scalar HT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

plt.hist(Cuts_sht_array, bins=np.arange(0,1500,10), alpha=0.4, label='SM ll+jjj ht cut 250', color = 'C8')
plt.title('Scalar HT')
plt.xlabel('Scalar HT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
plt.hist(DM.nJets, bins=np.arange(0,10,1), alpha=0.4, label='2HDMa ll+xdxd', color = 'C3')
plt.hist(Cuts.nJets, bins=np.arange(0,10,1), alpha=0.4, label='SM ll+jjj ht cut 250', color = 'C8')
plt.title('Number of Jets')
plt.xlabel('Number of Jets')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
plt.hist(DM.dileptonPT, bins=np.arange(0,500,5), alpha=0.4, label='2HDMa ll+xdxd', color = 'C3')
plt.hist(Cuts.dileptonPT, bins=np.arange(0,500,5), alpha=0.4, label='SM ll+jjj ht cut 250', color = 'C8')
plt.title('Dilepton PT')
plt.xlabel('Dilepton PT [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
plt.hist(DM.dileptonMass, bins=np.arange(0,200,2), alpha=0.4, label='2HDMa ll+xdxd', color = 'C3')
plt.hist(Cuts.dileptonMass, bins=np.arange(0,200,2), alpha=0.4, label='SM ll+jjj ht cut 250', color = 'C8')
plt.title('Dilepton Mass')
plt.xlabel('Dilepton Mass [GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()

# %%
DM_met_array=[]

for i,arr in enumerate (DM.l_missingET_met):
    for j,value in enumerate(arr):
        DM_met_array.append(value)

# %%
Cuts_met_array=[]

for i,arr in enumerate (Cuts.l_missingET_met):
    for j,value in enumerate(arr):
        Cuts_met_array.append(value)

# %%
plt.hist(DM_met_array, bins=np.arange(0,300,3), alpha=0.4, label='2HDMa ll+xdxd', color = 'C3')
plt.hist(Cuts_met_array, bins=np.arange(0,300,3), alpha=0.4, label='SM ll+jjj ht cut 250', color = 'C8')
plt.title('Missing ET')
plt.xlabel('Missing ET[GeV]')
plt.ylabel('Entries / Bin')
plt.legend()
plt.show()
